# %%
# !pip install altair vega_datasets

# %%
import pandas as pd
import altair as alt

# Habilita renderizado de Altair dentro de Colab
alt.renderers.enable('default')
# Out:
# RendererRegistry.enable('default')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b83286dc-5555-470a-8a64-042d71e5e3e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b83286dc-5555-470a-8a64-042d71e5e3e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Cargar el archivo Excel (ajusta el nombre si es distinto)
df = pd.read_excel("RANKING DE DENUNCIAS 2012-2022_BUENO.xlsx")

# %%
# Revisa las columnas únicas que hay
print(df.columns)
df.head()
# Out:
# Index(['unnamed:_0', 'unnamed:_1', 'unnamed:_2', 'unnamed:_3', 'unnamed:_4',
#        'unnamed:_5', 'unnamed:_6'],
#       dtype='object')
#                     unnamed:_0              unnamed:_1            unnamed:_2  \
# 0  CANAL / CABLE ESTANDARIZADO  Canal / Cable Operador              Programa
# 1                          TVN                     TVN  Esto no tiene nombre
# 2                         MEGA                    MEGA  Morandé con Compañía
# 3                  CHILEVISIÓN             CHILEVISIÓN            En la Mira
# 4                        MEGA                    MEGA            Mucho Gusto
#
#      unnamed:_3                                         unnamed:_4 unnamed:_5  \
# 0  Nº Denuncias                             Contenidos Denunciados        MES
# 1            48  Reportaje sensacionalista, con escenas de truc...       MAYO
# 2            14  Rutina humorística que ofende al culto evangél...       MAYO
# ...

# %%
# Esto permite ver hasta 1000 filas completas
pd.set_option('display.max_rows', 1000)      # Cambia 1000 por lo que necesites
pd.set_option('display.max_columns', None)   # Muestra todas las columnas
pd.set_option('display.width', None)         # Evita cortes de línea
pd.set_option('display.max_colwidth', None)  # Muestra el contenido completo de cada celda

# Ahora muestra el DataFrame completo
df
# Out:
#                                     Unnamed: 0  \
# 0                  CANAL / CABLE ESTANDARIZADO
# 1                                          TVN
# 2                                         MEGA
# 3                                  CHILEVISIÓN
# 4                                        MEGA
# 5                                     CANAL 13
# 6                                         MEGA
# 7                                      LA RED
# 8                                      LA RED
# 9                                      LA RED
# 10                                       MEGA
# 11                                         TVN
# 12                                       MEGA
# 13                                         TVN
# 14                                         TVN
# 15                                         TVN
# 16                                        MEGA
# 17                                         TVN
# 18                                 CHILEVISIÓN
# ...
